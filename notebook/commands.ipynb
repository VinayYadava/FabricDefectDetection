# %%
# !git clone https://github.com/plutoyuxie/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-.git
# Out:
# Cloning into 'AutoEncoder-SSIM-for-unsupervised-anomaly-detection-'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 72 (delta 30), reused 64 (delta 22), pack-reused 0
# Unpacking objects: 100% (72/72), 328.55 KiB | 1.58 MiB/s, done.

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !wget https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420937484-1629951672/carpet.tar.xz
# Out:
# --2023-02-07 19:21:01--  https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420937484-1629951672/carpet.tar.xz
# Resolving www.mydrive.ch (www.mydrive.ch)... 91.214.169.64
# Connecting to www.mydrive.ch (www.mydrive.ch)|91.214.169.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 740285760 (706M) [application/x-xz]
# Saving to: ‘carpet.tar.xz’
#
# carpet.tar.xz       100%[===================>] 705.99M  22.0MB/s    in 34s
#
# 2023-02-07 19:21:35 (20.9 MB/s) - ‘carpet.tar.xz’ saved [740285760/740285760]

# %%
# !sudo apt install xz-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xz-utils is already the newest version (5.2.4-1ubuntu1.1).
# xz-utils set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.

# %%
# %cd /content
# !mkdir data
# !mkdir test
# Out:
# /content

# %%
# !xz --decompress /content/drive/MyDrive/carpet.tar.xz

# %%
# !tar -C /content/data -xvf /content/drive/MyDrive/carpet.tar
# Out:
# carpet/
# carpet/ground_truth/
# carpet/ground_truth/color/
# carpet/ground_truth/color/016_mask.png
# carpet/ground_truth/color/017_mask.png
# carpet/ground_truth/color/018_mask.png
# carpet/ground_truth/color/000_mask.png
# carpet/ground_truth/color/001_mask.png
# carpet/ground_truth/color/002_mask.png
# carpet/ground_truth/color/003_mask.png
# carpet/ground_truth/color/004_mask.png
# carpet/ground_truth/color/005_mask.png
# carpet/ground_truth/color/006_mask.png
# carpet/ground_truth/color/007_mask.png
# carpet/ground_truth/color/008_mask.png
# carpet/ground_truth/color/009_mask.png
# carpet/ground_truth/color/010_mask.png
# carpet/ground_truth/color/011_mask.png
# carpet/ground_truth/color/012_mask.png
# carpet/ground_truth/color/013_mask.png
# carpet/ground_truth/color/014_mask.png
# carpet/ground_truth/color/015_mask.png
# carpet/ground_truth/cut/
# carpet/ground_truth/cut/000_mask.png
# carpet/ground_truth/cut/001_mask.png
# carpet/ground_truth/cut/002_mask.png
# ...

# %%
cd /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-
# Out:
# /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-

# %%
# !python train.py --name carpet --loss ssim_loss --im_resize 512 --patch_size 128 --z_dim 100 --do_aug
# Out:
# Traceback (most recent call last):
#   File "train.py", line 15, in <module>
#     cfg = Options().parse()
#   File "/content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/options.py", line 54, in parse
#     self.opt.sub_folder = os.listdir(self.opt.test_dir)
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/user/dataset/mvtec_anomaly_detection/carpet/test'

# %%
# %cd /content/drive/MyDrive
# !zip results.zip  /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/results
# Out:
# /content/drive/MyDrive
# 	zip warning: name not matched: /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/results
#
# zip error: Nothing to do! (results.zip)

# %%
# !unzip /content/drive/MyDrive/results.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/results.zip
#    creating: /content/results/
#    creating: /content/results/carpet/
#    creating: /content/results/carpet/chechpoints/
#    creating: /content/results/carpet/chechpoints/ssim_loss/
#   inflating: /content/results/carpet/chechpoints/ssim_loss/95-0.32117.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/52-0.33204.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/110-0.32056.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/51-0.33327.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/10-0.59695.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/87-0.32164.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/42-0.34374.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/30-0.46505.hdf5
#   inflating: /content/results/carpet/chechpoints/ssim_loss/72-0.32373.hdf5
# ...

# %%
# !mkdir /content/test_results

# %%
cd /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-
# Out:
# /content/AutoEncoder-SSIM-for-unsupervised-anomaly-detection-

# %%
# !python test.py --chechpoint_dir /content/results/carpet/chechpoints --weight_file /ssim_loss/01-0.89215.hdf5 --mask_size 512 --save_dir /content/test_results --train_data_dir /content/test --test_dir /content/test/ --loss ssim_loss --im_resize 512 --patch_size 128 --z_dim 100 --sub_folder vinay
# Out:
# 2023-02-08 10:31:03.060304: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# estimating threshold...
# 6/6 [==============================] - 3s 441ms/step
# [[[0.84711093 0.84589882 0.88218564 ... 0.92441362 0.92417416 0.93273383]
#   [0.88268348 0.870058   0.8946796  ... 0.94073932 0.93917996 0.94415538]
#   [0.89786479 0.88085854 0.89927949 ... 0.9396663  0.93768265 0.94298263]
#   ...
#   [0.89944778 0.90382641 0.90714668 ... 0.96433133 0.95709084 0.95600041]
#   [0.82993725 0.84719769 0.86803804 ... 0.96947287 0.97112906 0.97331525]
#   [0.779724   0.80819502 0.84542439 ... 0.9747741  0.97548233 0.97753547]]]
# ssim_threshold: 0.967661, l1_threshold: 0.286275
# yesss
# bakchodi
# fcgfc /content/test/Fabric10.png
# bokachoda Fabric10
# 6/6 [==============================] - 1s 235ms/step
# /content/test_results/Fabric10_residual.png
# madarchod
# fcgfc /content/test/Fabric13.png
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !zip -r /content/drive/MyDrive/Repositories/AutoEncoder-SSIM-for-unsupervised-anomaly-detection.zip AutoEncoder-SSIM-for-unsupervised-anomaly-detection-
# Out:
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/ (stored 0%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/image/ (stored 0%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/image/bent_000_rec.png (deflated 18%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/image/bent_000_visual.png (deflated 17%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/image/bent_000_residual.png (deflated 35%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/image/bent_000_origin.png (deflated 17%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/README.md (deflated 78%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/test.py (deflated 70%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/__pycache__/ (stored 0%)
#   adding: AutoEncoder-SSIM-for-unsupervised-anomaly-detection-/__pycache__/network.cpython-38.pyc (deflated 55%)
# ...

# %%
cd /content/drive/MyDrive/Repositories/
